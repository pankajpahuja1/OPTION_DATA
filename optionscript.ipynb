# %%
import pandas as pd;
df=pd.read_csv("OPTIDX_NIFTY_PE_01-Jan-2021_TO_28-Jan-2021.csv")
df.columns
# Out:
# Index(['Symbol', 'Date', 'Expiry', 'Option Type', 'Strike Price', 'Open',
#        'High', 'Low', 'Close', 'LTP', 'Settle Price', 'No. of contracts',
#        'Turnover in Lacs', 'Premium Turnover in Lacs', 'Open Int',
#        'Change in OI', 'Underlying Value'],
#       dtype='object')

# %%
ff=df[['Symbol', 'Date', 'Expiry', 'Option Type']]
kk=pd.DataFrame(df['Strike Price'])
kk.head()
kj=pd.DataFrame(df['Date'])
kl=pd.DataFrame(df['Settle Price'],columns=kj,index=kk)
kl=pd.DataFrame(df['Settle Price'],columns=kj)
kl
kl=pd.DataFrame(df['Settle Price'],columns=kj,index=kk)
dj=df.T
df.columns
# Out:
# Index(['Symbol', 'Date', 'Expiry', 'Option Type', 'Strike Price', 'Open',
#        'High', 'Low', 'Close', 'LTP', 'Settle Price', 'No. of contracts',
#        'Turnover in Lacs', 'Premium Turnover in Lacs', 'Open Int',
#        'Change in OI', 'Underlying Value'],
#       dtype='object')

# %%
df.head()
df=df.drop(['Symbol','Open','High', 'Low', 'Close', 'LTP','No. of contracts','Turnover in Lacs', 'Premium Turnover in Lacs', 'Open Int',
       'Change in OI'],axis=1)

# %%
dj=(df.T)
df.columns
dj.head(7)
# Out:
#                          0            1            2            3     \
# Date              01-Jan-2021  01-Jan-2021  01-Jan-2021  01-Jan-2021
# Expiry            28-Jan-2021  28-Jan-2021  28-Jan-2021  28-Jan-2021
# Option Type                PE           PE           PE           PE
# Strike Price            13350        13400        13450        13500
# Settle Price             75.9         83.7        93.05        102.6
# Underlying Value      14018.5      14018.5      14018.5      14018.5
#
#                          4            5            6            7     \
# Date              01-Jan-2021  01-Jan-2021  01-Jan-2021  01-Jan-2021
# Expiry            28-Jan-2021  28-Jan-2021  28-Jan-2021  28-Jan-2021
# Option Type                PE           PE           PE           PE
# Strike Price            13550        13600        13650        13700
# Settle Price           117.15       128.05        142.5       151.45
# ...

# %%
df.set_index('Date').T
# Out:
# Date              01-Jan-2021  01-Jan-2021  01-Jan-2021  01-Jan-2021  \
# Expiry            28-Jan-2021  28-Jan-2021  28-Jan-2021  28-Jan-2021
# Option Type                PE           PE           PE           PE
# Strike Price            13350        13400        13450        13500
# Settle Price             75.9         83.7        93.05        102.6
# Underlying Value      14018.5      14018.5      14018.5      14018.5
#
# Date              01-Jan-2021  01-Jan-2021  01-Jan-2021  01-Jan-2021  \
# Expiry            28-Jan-2021  28-Jan-2021  28-Jan-2021  28-Jan-2021
# Option Type                PE           PE           PE           PE
# Strike Price            13550        13600        13650        13700
# Settle Price           117.15       128.05        142.5       151.45
# Underlying Value      14018.5      14018.5      14018.5      14018.5
#
# Date              01-Jan-2021  01-Jan-2021  ...  28-Jan-2021  28-Jan-2021  \
# ...

# %%
df.set_index('Date').T
# Out:
# Date              01-Jan-2021  01-Jan-2021  01-Jan-2021  01-Jan-2021  \
# Expiry            28-Jan-2021  28-Jan-2021  28-Jan-2021  28-Jan-2021
# Option Type                PE           PE           PE           PE
# Strike Price            13350        13400        13450        13500
# Settle Price             75.9         83.7        93.05        102.6
# Underlying Value      14018.5      14018.5      14018.5      14018.5
#
# Date              01-Jan-2021  01-Jan-2021  01-Jan-2021  01-Jan-2021  \
# Expiry            28-Jan-2021  28-Jan-2021  28-Jan-2021  28-Jan-2021
# Option Type                PE           PE           PE           PE
# Strike Price            13550        13600        13650        13700
# Settle Price           117.15       128.05        142.5       151.45
# Underlying Value      14018.5      14018.5      14018.5      14018.5
#
# Date              01-Jan-2021  01-Jan-2021  ...  28-Jan-2021  28-Jan-2021  \
# ...

# %%
a=df['Date'].unique()
list(a)
# for i in df['Date']:
#     print(i)
for i in a:
    if j in df['Date']:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-121e9480ee36> in <module>
#       4 #     print(i)
#       5 for i in a:
# ----> 6     if j in df['Date']:
#       7         print(i)
#
# NameError: name 'j' is not defined

# %%
strike=df['Strike Price'].unique()
list(strike)
# Out:
# [13350,
#  13400,
#  13450,
#  13500,
#  13550,
#  13600,
#  13650,
#  13700,
#  13750,
#  13800,
#  13850,
#  13900,
#  13950,
#  14000,
#  14050,
#  14100,
#  14150,
#  14200,
#  14250,
#  14300,
#  14350,
#  14400,
#  14450,
#  14500,
#  14550,
#  14600,
#  14650,
#  14700,
#  14750,
#  14800,
#  14850,
#  14900,
#  14950,
#  15000,
#  15050,
#  15100,
#  15150,
#  15200,
#  15250,
#  15300,
#  15350,
#  15400,
#  15450,
#  15500,
#  10150,
#  10200,
#  10250,
#  10300,
#  10350,
#  10400,
#  10450,
#  10500,
#  10550,
#  10600,
#  10650,
#  10700,
#  10750,
#  10800,
#  10850,
#  10900,
#  10950,
#  11000,
#  11050,
#  11100,
#  11150,
#  11200,
#  11250,
#  11300,
#  11350,
#  11400,
#  11450,
#  11500,
#  11550,
#  11600,
#  11650,
#  11700,
#  11750,
#  11800,
#  11850,
#  11900,
#  11950,
#  12000,
#  12050,
#  12100,
#  12150,
#  12200,
#  12250,
#  12300,
#  12350,
#  12400,
#  12450,
#  12500,
#  12550,
#  12600,
#  12650,
#  12700,
#  12750,
#  12800,
#  12850,
#  12900,
# ...

# %%
len(a)
type(a[0])
# Out:
# numpy.int64

# %%
list=[]
for i ,j in enumerate(strike):
    list.append(df['Strike Price'][i])
list
# Out:
# [13350,
#  13400,
#  13450,
#  13500,
#  13550,
#  13600,
#  13650,
#  13700,
#  13750,
#  13800,
#  13850,
#  13900,
#  13950,
#  14000,
#  14050,
#  14100,
#  14150,
#  14200,
#  14250,
#  14300,
#  14350,
#  14400,
#  14450,
#  14500,
#  14550,
#  14600,
#  14650,
#  14700,
#  14750,
#  14800,
#  14850,
#  14900,
#  14950,
#  15000,
#  15050,
#  15100,
#  15150,
#  15200,
#  15250,
#  15300,
#  15350,
#  15400,
#  15450,
#  15500,
#  10150,
#  10200,
#  10250,
#  10300,
#  10350,
#  10400,
#  10450,
#  10500,
#  10550,
#  10600,
#  10650,
#  10700,
#  10750,
#  10800,
#  10850,
#  10900,
#  10950,
#  11000,
#  11050,
#  11100,
#  11150,
#  11200,
#  11250,
#  11300,
#  11350,
#  11400,
#  11450,
#  11500,
#  11550,
#  11600,
#  11650,
#  11700,
#  11750,
#  11800,
#  11850,
#  11900,
#  11950,
#  12000,
#  12050,
#  12100,
#  12150,
#  12200,
#  12250,
#  12300,
#  12350,
#  12400,
#  12450,
#  12500,
#  12550,
#  12600,
#  12650,
#  12700,
#  12750,
#  12800,
#  12850,
#  12900,
# ...

# %%
k
# Out:
# {'04-Jan-2021': ['']}

# %%
for i ,j in enumerate(strike):
    print(i,j)
# Out:
# 0 13350
# 1 13400
# 2 13450
# 3 13500
# 4 13550
# 5 13600
# 6 13650
# 7 13700
# 8 13750
# 9 13800
# 10 13850
# 11 13900
# 12 13950
# 13 14000
# 14 14050
# 15 14100
# 16 14150
# 17 14200
# 18 14250
# 19 14300
# 20 14350
# 21 14400
# 22 14450
# 23 14500
# 24 14550
# 25 14600
# 26 14650
# 27 14700
# 28 14750
# 29 14800
# 30 14850
# 31 14900
# 32 14950
# 33 15000
# 34 15050
# 35 15100
# 36 15150
# 37 15200
# 38 15250
# 39 15300
# 40 15350
# 41 15400
# 42 15450
# 43 15500
# 44 10150
# 45 10200
# 46 10250
# 47 10300
# 48 10350
# 49 10400
# 50 10450
# 51 10500
# 52 10550
# 53 10600
# 54 10650
# 55 10700
# 56 10750
# 57 10800
# 58 10850
# 59 10900
# 60 10950
# 61 11000
# 62 11050
# 63 11100
# 64 11150
# 65 11200
# 66 11250
# 67 11300
# 68 11350
# 69 11400
# 70 11450
# 71 11500
# 72 11550
# 73 11600
# 74 11650
# 75 11700
# 76 11750
# 77 11800
# 78 11850
# 79 11900
# 80 11950
# 81 12000
# 82 12050
# 83 12100
# 84 12150
# 85 12200
# 86 12250
# 87 12300
# 88 12350
# 89 12400
# 90 12450
# ...

# %%
list=[]
for j in strike:
    list.append(df['Strike Price'])
list
# Out:
#   13400
#  2       13450
#  3       13500
#  4       13550
#          ...
#  2214    13100
#  2215    13150
#  2216    13200
#  2217    13250
#  2218    13300
#  Name: Strike Price, Length: 2219, dtype: int64, 0       13350
#  1       13400
#  2       13450
#  3       13500
#  4       13550
#          ...
#  2214    13100
#  2215    13150
#  2216    13200
#  2217    13250
#  2218    13300
#  Name: Strike Price, Length: 2219, dtype: int64, 0       13350
#  1       13400
#  2       13450
#  3       13500
#  4       13550
#          ...
#  2214    13100
#  2215    13150
#  2216    13200
#  2217    13250
#  2218    13300
#  Name: Strike Price, Length: 2219, dtype: int64, 0       13350
#  1       13400
#  2       13450
#  3       13500
#  4       13550
#          ...
#  2214    13100
#  2215    13150
#  2216    13200
#  2217    13250
#  2218    13300
#  Name: Strike Price, Length: 2219, dtype: int64, 0       13350
#  1       13400
#  2       13450
#  3       13500
#  4       13550
# ...

# %%
df
# Out:
#      Symbol         Date       Expiry Option Type  Strike Price    Open  \
# 0     NIFTY  01-Jan-2021  28-Jan-2021          PE         13350   98.30
# 1     NIFTY  01-Jan-2021  28-Jan-2021          PE         13400  121.05
# 2     NIFTY  01-Jan-2021  28-Jan-2021          PE         13450  119.15
# 3     NIFTY  01-Jan-2021  28-Jan-2021          PE         13500  139.90
# 4     NIFTY  01-Jan-2021  28-Jan-2021          PE         13550  140.25
# ...     ...          ...          ...         ...           ...     ...
# 2214  NIFTY  28-Jan-2021  28-Jan-2021          PE         13100    0.50
# 2215  NIFTY  28-Jan-2021  28-Jan-2021          PE         13150    0.30
# 2216  NIFTY  28-Jan-2021  28-Jan-2021          PE         13200    0.70
# 2217  NIFTY  28-Jan-2021  28-Jan-2021          PE         13250    0.50
# 2218  NIFTY  28-Jan-2021  28-Jan-2021          PE         13300    1.60
#
#         High     Low   Close     LTP  Settle Price  No. of contracts  \
# ...
