# %%
import pandas as pd;

# %%
df=pd.read_csv("OPTIDX_NIFTY_PE_01-Jan-2021_TO_28-Jan-2021.csv")

# %%
df.columns
# Out:
# Index(['Symbol', 'Date', 'Expiry', 'Option Type', 'Strike Price', 'Open',
#        'High', 'Low', 'Close', 'LTP', 'Settle Price', 'No. of contracts',
#        'Turnover in Lacs', 'Premium Turnover in Lacs', 'Open Int',
#        'Change in OI', 'Underlying Value'],
#       dtype='object')

# %%
df=df.drop('Premium Turnover in Lacs',axis='columns')

# %%
df.columns
# Out:
# Index(['Symbol', 'Date', 'Expiry', 'Option Type', 'Strike Price', 'Open',
#        'High', 'Low', 'Close', 'LTP', 'Settle Price', 'No. of contracts',
#        'Turnover in Lacs', 'Open Int', 'Change in OI', 'Underlying Value'],
#       dtype='object')

# %%
df['Underlying Value']
# Out:
# 0        14018.5
# 1        14018.5
# 2        14018.5
# 3        14018.5
# 4        14018.5
#           ...
# 2214    13817.55
# 2215    13817.55
# 2216    13817.55
# 2217    13817.55
# 2218    13817.55
# Name: Underlying Value, Length: 2219, dtype: object

# %%
import nsetools as ns
ns.nse
from nsetools import Nse
nse=Nse()
all_stock_codes = nse.get_stock_codes()
#all_stock_codes

# %%
# for index,i in df['Underlying Value']:
    
#     if i=='-':
#         df['Underlying Value'][index]=(int(k/100))*100
#         i=k
#     else:
#         i=float(i)
#         df['Underlying Value'][index]=(int(i/100))*100
#     k=i
# print(type(k),type(i))

# %%
df.head()
# Out:
#   Symbol         Date       Expiry Option Type  Strike Price    Open    High  \
# 0  NIFTY  01-Jan-2021  28-Jan-2021          PE         13350   98.30   98.85
# 1  NIFTY  01-Jan-2021  28-Jan-2021          PE         13400  121.05  121.05
# 2  NIFTY  01-Jan-2021  28-Jan-2021          PE         13450  119.15  119.20
# 3  NIFTY  01-Jan-2021  28-Jan-2021          PE         13500  139.90  139.90
# 4  NIFTY  01-Jan-2021  28-Jan-2021          PE         13550  140.25  140.25
#
#      Low   Close     LTP  Settle Price  No. of contracts  Turnover in Lacs  \
# 0   71.6   75.90   75.45         75.90               176           1772.62
# 1   79.4   83.70   84.50         83.70              5848          59164.56
# 2   88.0   93.05   93.90         93.05               487           4948.54
# 3   97.5  102.60  103.00        102.60             23788         242798.10
# 4  107.4  117.15  112.95        117.15               406           4163.64
#
#    Open Int  Change in OI Underlying Value
# ...

# %%
df.loc[df['Underlying Value'][0]]=float(df['Underlying Value'][0])

df.loc[df['Underlying Value'][0]]=(int(df['Underlying Value'][0]/100))*100
df.loc[df['Underlying Value'][0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-eb9619628d27> in <module>
#       1 df.loc[df['Underlying Value'][0]]=float(df['Underlying Value'][0])
#       2
# ----> 3 df.loc[df['Underlying Value'][0]]=(int(df['Underlying Value'][0]/100))*100
#       4 df.loc[df['Underlying Value'][0]]
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
df['Underlying Value']
# Out:
# 0           14018.5
# 1           14018.5
# 2           14018.5
# 3           14018.5
# 4           14018.5
#              ...
# 2215       13817.55
# 2216       13817.55
# 2217       13817.55
# 2218       13817.55
# 14018.5     14018.5
# Name: Underlying Value, Length: 2220, dtype: object

# %%
(int(10801/100))*100
# Out:
# 10800

# %%
df['Underlying Value'].unique()
# Out:
# array(['14018.5', '14132.9', '-', '14137.35', '14484.75', '14563.45',
#        '14595.6', '14433.7', '14521.15', '14644.7', '14590.35', '14371.9',
#        '14238.9', '13967.5', '13817.55', 14018.5], dtype=object)

# %%
for index,row in df.iterrows():
    print(row['Underlying Value'])
# Out:
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# 14018.5
# ...

# %%
for index,i in df.iterrows():
    
    if i['Underlying Value']=='-':
        df['Underlying Value'][index]=(int(k/100))*100
        i['Underlying Value']=k['Underlying Value']
    else:
       
        df['Underlying Value'][index]=(int(i['Underlying Value']/100))*100
    k['Underlying Value']=i['Underlying Value']
print(type(k),type(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-4006493f0175> in <module>
#       6     else:
#       7
# ----> 8         df['Underlying Value'][index]=(int(i['Underlying Value']/100))*100
#       9     k['Underlying Value']=i['Underlying Value']
#      10 print(type(k),type(i))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
for j,i in df.iterrows():
    print(i)
# Out:
#   0
# Change in OI                  0
# Underlying Value          13800
# Name: 2181, dtype: object
# Symbol                    NIFTY
# Date                28-Jan-2021
# Expiry              28-Jan-2021
# Option Type                  PE
# Strike Price              11500
# Open                        0.3
# High                        0.3
# Low                        0.05
# Close                       0.1
# LTP                        0.05
# Settle Price            13817.5
# No. of contracts           6596
# Turnover in Lacs        56891.3
# Open Int                 721050
# Change in OI             -22875
# Underlying Value          13800
# Name: 2182, dtype: object
# Symbol                    NIFTY
# Date                28-Jan-2021
# Expiry              28-Jan-2021
# Option Type                  PE
# Strike Price              11550
# Open                       0.15
# High                       0.15
# Low                        0.15
# Close                      0.15
# ...

# %%
import pandas as pd;
df=pd.read_csv("OPTIDX_NIFTY_PE_01-Jan-2021_TO_28-Jan-2021.csv",index_col='Strike Price')
df=df.drop(['Symbol','Open','High', 'Low', 'Close', 'LTP','No. of contracts','Turnover in Lacs', 'Premium Turnover in Lacs', 'Open Int',
       'Change in OI'],axis=1)
date=df['Date'].unique()
list(date)
strike=df.index.unique()
list(strike)
settle=df['Settle Price']

#data not working

# %%
k=pd.DataFrame(data=df['Settle Price'],columns=list(date),index=list(strike))

# %%
for dt in date:
    for strikep in df.index:
        if dt in df.at[strikep,'Date']:
            for setle in settle:
                print(setle)
# Out:
# 1095.1
# 1144.1
# 1193.3
# 1242.6
# 1292.1
# 1353.65
# 1391.3
# 1441.05
# 0.05
# 0.85
# 0.05
# 0.85
# 0.05
# 0.05
# 0.05
# 0.7
# 0.05
# 0.05
# 0.05
# 0.7
# 0.05
# 1.55
# 0.05
# 0.05
# 0.05
# 0.7
# 0.05
# 0.95
# 0.05
# 0.8
# 0.05
# 1.0
# 0.05
# 0.95
# 0.05
# 1.6
# 0.05
# 1.0
# 0.05
# 1.5
# 0.05
# 2.0
# 0.05
# 1.45
# 0.05
# 1.85
# 2.0
# 2.1
# 0.05
# 2.0
# 0.05
# 2.35
# 0.05
# 2.3
# 0.05
# 2.35
# 0.05
# 2.45
# 0.05
# 2.5
# 0.05
# 2.35
# 0.05
# 2.3
# 2.3
# 2.65
# 2.55
# 2.75
# 2.9
# 3.0
# 3.35
# 3.9
# 6.95
# 7.5
# 8.1
# 9.45
# 10.6
# 11.25
# 12.65
# 13.75
# 15.3
# 17.15
# 17.75
# 22.1
# 24.35
# 28.75
# 31.15
# 35.9
# 40.4
# 44.75
# 52.2
# 58.6
# 69.95
# 77.55
# 95.95
# 106.55
# 127.6
# 145.5
# 166.3
# 196.4
# 229.7
# 257.95
# 302.2
# 327.7
# 383.6
# 407.95
# 460.0
# 501.45
# 580.9
# 613.45
# 643.65
# 700.3
# 802.7
# 840.4
# 833.45
# 915.45
# 952.7
# 1001.4
# 1050.35
# 1108.85
# 1148.8
# 1255.35
# 1247.9
# 1297.55
# 1347.3
# 1400.4
# 1446.9
# 1496.8
# 1546.65
# 0.9
# 0.8
# 0.05
# 0.4
# ...

# %%
import pandas as pd;
df=pd.read_csv("OPTIDX_NIFTY_PE_01-Jan-2021_TO_28-Jan-2021.csv",index_col=['Date','Strike Price'])
df=df.drop(['Symbol','Open','High', 'Low', 'Close', 'LTP','No. of contracts','Turnover in Lacs', 'Premium Turnover in Lacs', 'Open Int',
       'Change in OI'],axis=1)

# %%
date=df['Date'].unique()
list(date)
strike=df.index.unique()
list(strike)
settle=df['Settle Price']
list(strike)
#data not working
k=pd.DataFrame(data=df['Settle Price'],columns=list(date),index=list(strike))
k
for dt in date:
    for strikep in df.index:
        
         if dt in df.at[strikep,'Date']:
             for setle in settle:
                k.at[strikep,dt]=df.at[strikep,'Settle Price']

# %%
df
# Out:
#                                Expiry Option Type  Settle Price  \
# Strike Price Date
# 13350        01-Jan-2021  28-Jan-2021          PE         75.90
# 13400        01-Jan-2021  28-Jan-2021          PE         83.70
# 13450        01-Jan-2021  28-Jan-2021          PE         93.05
# 13500        01-Jan-2021  28-Jan-2021          PE        102.60
# 13550        01-Jan-2021  28-Jan-2021          PE        117.15
# ...                               ...         ...           ...
# 13100        28-Jan-2021  28-Jan-2021          PE      13817.55
# 13150        28-Jan-2021  28-Jan-2021          PE      13817.55
# 13200        28-Jan-2021  28-Jan-2021          PE      13817.55
# 13250        28-Jan-2021  28-Jan-2021          PE      13817.55
# 13300        28-Jan-2021  28-Jan-2021          PE      13817.55
#
#                          Underlying Value
# Strike Price Date
# 13350        01-Jan-2021          14018.5
# 13400        01-Jan-2021          14018.5
# ...

# %%
df.loc[[13350],'Settle Price']
# Out:
# Strike Price  Date
# 13350         01-Jan-2021       75.90
#               04-Jan-2021       56.30
#               05-Jan-2021       54.05
#               06-Jan-2021       55.40
#               07-Jan-2021       44.35
#               08-Jan-2021       31.60
#               11-Jan-2021       29.70
#               12-Jan-2021       25.40
#               13-Jan-2021       21.05
#               14-Jan-2021       17.15
#               15-Jan-2021       22.50
#               18-Jan-2021       23.20
#               19-Jan-2021        8.30
#               20-Jan-2021        4.10
#               21-Jan-2021        6.95
#               22-Jan-2021        3.45
#               25-Jan-2021        1.60
#               27-Jan-2021        1.75
#               28-Jan-2021    13817.55
# Name: Settle Price, dtype: float64

# %%
list=[]
print(type(list))
list=df.index.levels[0].unique()
list
# Out:
# <class 'list'>
# Int64Index([10150, 10200, 10250, 10300, 10350, 10400, 10450, 10500, 10550,
#             10600,
#             ...
#             15700, 15750, 15800, 15850, 15900, 15950, 16000, 16050, 16100,
#             16150],
#            dtype='int64', name='Strike Price', length=121)

# %%
df.loc[['07-Jan-2021',13450]].at['Settle price']
#df.loc[['01-Jan-2021']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-3ca9de4b3087> in <module>
# ----> 1 df.loc[['07-Jan-2021',13450]].at['Settle price']
#       2 #df.loc[['01-Jan-2021']]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2198
#    2199         key = self._convert_key(key)
# -> 2200         return self.obj._get_value(*key, takeable=self._takeable)
#    2201
#    2202     def __setitem__(self, key, value):
#
# TypeError: _get_value() missing 1 required positional argument: 'col'

# %%
df.index.levels
# Out:
# FrozenList([[10150, 10200, 10250, 10300, 10350, 10400, 10450, 10500, 10550, 10600, 10650, 10700, 10750, 10800, 10850, 10900, 10950, 11000, 11050, 11100, 11150, 11200, 11250, 11300, 11350, 11400, 11450, 11500, 11550, 11600, 11650, 11700, 11750, 11800, 11850, 11900, 11950, 12000, 12050, 12100, 12150, 12200, 12250, 12300, 12350, 12400, 12450, 12500, 12550, 12600, 12650, 12700, 12750, 12800, 12850, 12900, 12950, 13000, 13050, 13100, 13150, 13200, 13250, 13300, 13350, 13400, 13450, 13500, 13550, 13600, 13650, 13700, 13750, 13800, 13850, 13900, 13950, 14000, 14050, 14100, 14150, 14200, 14250, 14300, 14350, 14400, 14450, 14500, 14550, 14600, 14650, 14700, 14750, 14800, 14850, 14900, 14950, 15000, 15050, 15100, ...], ['01-Jan-2021', '04-Jan-2021', '05-Jan-2021', '06-Jan-2021', '07-Jan-2021', '08-Jan-2021', '11-Jan-2021', '12-Jan-2021', '13-Jan-2021', '14-Jan-2021', '15-Jan-2021', '18-Jan-2021', '19-Jan-2021', '20-Jan-2021', '21-Jan-2021', '22-Jan-2021', '25-Jan-2021', '27-Jan-2021', '28-Jan-
# ...

# %%
df.loc['07-Jan-2021']
# Out:
#                    Expiry Option Type  Settle Price Underlying Value
# Strike Price
# 13350         28-Jan-2021          PE         44.35         14137.35
# 13400         28-Jan-2021          PE         49.60         14137.35
# 13450         28-Jan-2021          PE         55.30         14137.35
# 13500         28-Jan-2021          PE         61.35         14137.35
# 13550         28-Jan-2021          PE         68.95         14137.35
# ...                   ...         ...           ...              ...
# 13100         28-Jan-2021          PE         25.75         14137.35
# 13150         28-Jan-2021          PE         28.30         14137.35
# 13200         28-Jan-2021          PE         31.75         14137.35
# 13250         28-Jan-2021          PE         35.25         14137.35
# 13300         28-Jan-2021          PE         39.95         14137.35
#
# [112 rows x 4 columns]

# %%
#
# Out:
#                                Expiry Option Type  Settle Price  \
# Date        Strike Price
# 07-Jan-2021 13350         28-Jan-2021          PE         44.35
#
#                          Underlying Value
# Date        Strike Price
# 07-Jan-2021 13350                14137.35

# %%
df
# Out:
#                                Expiry Option Type  Settle Price  \
# Date        Strike Price
# 01-Jan-2021 13350         28-Jan-2021          PE         75.90
#             13400         28-Jan-2021          PE         83.70
#             13450         28-Jan-2021          PE         93.05
#             13500         28-Jan-2021          PE        102.60
#             13550         28-Jan-2021          PE        117.15
# ...                               ...         ...           ...
# 28-Jan-2021 13100         28-Jan-2021          PE      13817.55
#             13150         28-Jan-2021          PE      13817.55
#             13200         28-Jan-2021          PE      13817.55
#             13250         28-Jan-2021          PE      13817.55
#             13300         28-Jan-2021          PE      13817.55
#
#                          Underlying Value
# Date        Strike Price
# 01-Jan-2021 13350                 14018.5
#             13400                 14018.5
# ...

# %%
f=df.index.get_level_values(0).unique().tolist()
f
# Out:
# ['01-Jan-2021',
#  '04-Jan-2021',
#  '05-Jan-2021',
#  '06-Jan-2021',
#  '07-Jan-2021',
#  '08-Jan-2021',
#  '11-Jan-2021',
#  '12-Jan-2021',
#  '13-Jan-2021',
#  '14-Jan-2021',
#  '15-Jan-2021',
#  '18-Jan-2021',
#  '19-Jan-2021',
#  '20-Jan-2021',
#  '21-Jan-2021',
#  '22-Jan-2021',
#  '25-Jan-2021',
#  '27-Jan-2021',
#  '28-Jan-2021']

# %%
df.loc[[('01-Jan-2021',13350)],'Settle Price']
# Out:
# Date         Strike Price
# 01-Jan-2021  13350           75.9
# Name: Settle Price, dtype: float64

# %%
df
# Out:
#                                Expiry Option Type  Settle Price  \
# Date        Strike Price
# 01-Jan-2021 13350         28-Jan-2021          PE         75.90
#             13400         28-Jan-2021          PE         83.70
#             13450         28-Jan-2021          PE         93.05
#             13500         28-Jan-2021          PE        102.60
#             13550         28-Jan-2021          PE        117.15
# ...                               ...         ...           ...
# 28-Jan-2021 13100         28-Jan-2021          PE      13817.55
#             13150         28-Jan-2021          PE      13817.55
#             13200         28-Jan-2021          PE      13817.55
#             13250         28-Jan-2021          PE      13817.55
#             13300         28-Jan-2021          PE      13817.55
#
#                          Underlying Value
# Date        Strike Price
# 01-Jan-2021 13350                 14018.5
#             13400                 14018.5
# ...
